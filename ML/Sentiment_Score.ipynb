# %%
import pandas as pd

# %%
mbti_df = pd.read_csv("Resources/mbti.csv")

# %%
len(mbti_df)
# Out:
# 8675

# %%
posts = mbti_df['posts']
post_num = []
for i in range(0,len(posts)):
    post=posts[i].count("|||") + 1
    post_num.append(post)

# %%
len(post_num)
# Out:
# 8675

# %%
score = mbti_df[['type','posts']]
score.head()
# score['posts'][0]
# Out:
#    type                                              posts
# 0  INFJ  'http://www.youtube.com/watch?v=qsXHcwe3krw|||...
# 1  ENTP  'I'm finding the lack of me in these posts ver...
# 2  INTP  'Good one  _____   https://www.youtube.com/wat...
# 3  INTJ  'Dear INTP,   I enjoyed our conversation the o...
# 4  ENTJ  'You're fired.|||That's another silly misconce...

# %%
score = pd.concat([pd.Series(row['type'], row['posts'].split('|||'))              
                    for _, row in score.iterrows()]).reset_index()

# %%
len(score)
# Out:
# 422845

# %%
score = score.rename(columns={
    "index":"posts"
})
score.columns.values[1] = "type"

# %%
score
# Out:
#                                                     posts  type
# 0             'http://www.youtube.com/watch?v=qsXHcwe3krw  INFJ
# 1       http://41.media.tumblr.com/tumblr_lfouy03PMA1q...  INFJ
# 2       enfp and intj moments  https://www.youtube.com...  INFJ
# 3       What has been the most life-changing experienc...  INFJ
# 4       http://www.youtube.com/watch?v=vXZeYwwRDw8   h...  INFJ
# ...                                                   ...   ...
# 422840  I was going to close my facebook a few months ...  INFP
# 422841  30 Seconds to Mars - All of my collections. It...  INFP
# 422842  I have seen it, and i agree. I did actually th...  INFP
# 422843  Ok so i have just watched Underworld 4 (Awaken...  INFP
# 422844  I would never want to turn off my emotions. so...  INFP
#
# [422845 rows x 2 columns]

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# Target String Setting
target_string = score['posts']

# %%
len(target_string)
# Out:
# 422845

# %%
scores = []
for i in target_string:
    compound = analyzer.polarity_scores(i)["compound"]
    scores.append(compound)

# %%
len(scores)
# Out:
# 422845

# %%
score['sentiment_score_compound']= scores

# %%
score.head(55)
# Out:
#                                                 posts  type  \
# 0         'http://www.youtube.com/watch?v=qsXHcwe3krw  INFJ
# 1   http://41.media.tumblr.com/tumblr_lfouy03PMA1q...  INFJ
# 2   enfp and intj moments  https://www.youtube.com...  INFJ
# 3   What has been the most life-changing experienc...  INFJ
# 4   http://www.youtube.com/watch?v=vXZeYwwRDw8   h...  INFJ
# 5                May the PerC Experience immerse you.  INFJ
# 6   The last thing my INFJ friend posted on his fa...  INFJ
# 7   Hello ENFJ7. Sorry to hear of your distress. I...  INFJ
# 8   84389  84390  http://wallpaperpassion.com/uplo...  INFJ
# 9                                  Welcome and stuff.  INFJ
# 10  http://playeressence.com/wp-content/uploads/20...  INFJ
# 11  Prozac, wellbrutin, at least thirty minutes of...  INFJ
# 12  Basically come up with three items you've dete...  INFJ
# 13  All things in moderation.  Sims is indeed a vi...  INFJ
# 14  Dear ENFP:  What were your favorite video game...  INFJ
# 15        https://www.youtube.com/watch?v=QyPqT8umzmY  INFJ
# 16                   It appears to be too late. :sad:  INFJ
# 17            There's someone out there for everyone.  INFJ
# 18     Wait... I thought confidence was a good thing.  INFJ
# 19  I just cherish the time of solitude b/c i reve...  INFJ
# 20  Yo entp ladies... if you're into a complimenta...  INFJ
# 21  ... when your main social outlet is xbox live ...  INFJ
# 22  http://www.youtube.com/watch?v=gDhy7rdfm14  I ...  INFJ
# 23         http://www.youtube.com/watch?v=msqXffgh7b8  INFJ
# 24      Banned because this thread requires it of me.  INFJ
# 25  Get high in backyard, roast and eat marshmello...  INFJ
# 26         http://www.youtube.com/watch?v=Mw7eoU3BMbE  INFJ
# 27         http://www.youtube.com/watch?v=4V2uYORhQOk  INFJ
# 28         http://www.youtube.com/watch?v=SlVmgFQQ0TI  INFJ
# 29  Banned for too many b's in that sentence. How ...  INFJ
# 30  Banned for watching movies in the corner with ...  INFJ
# 31  Banned because Health class clearly taught you...  INFJ
# 32                Banned for a whole host of reasons!  INFJ
# 33         http://www.youtube.com/watch?v=IRcrv41hgz4  INFJ
# 34  1) Two baby deer on left and right munching on...  INFJ
# 35  a pokemon world  an infj society  everyone bec...  INFJ
# 36                                              49142  INFJ
# 37         http://www.youtube.com/watch?v=ZRCEq_JFeFM  INFJ
# 38  http://discovermagazine.com/2012/jul-aug/20-th...  INFJ
# 39  http://oyster.ignimgs.com/mediawiki/apis.ign.c...  INFJ
# 40          http://www.serebii.net/potw-dp/Scizor.jpg  INFJ
# 41  Not all artists are artists because they draw....  INFJ
# 42  Welcome to the robot ranks, person who downed ...  INFJ
# 43  Banned for taking all the room under my bed. Y...  INFJ
# 44         http://www.youtube.com/watch?v=w8IgImn57aQ  INFJ
# 45  Banned for being too much of a thundering, gru...  INFJ
# 46  Ahh... old high school music I haven't heard i...  INFJ
# 47  I failed a public speaking class a few years a...  INFJ
# 48  I like this person's mentality. He's a confirm...  INFJ
# 49  Move to the Denver area and start a new life f...  INFJ
# 50  'I'm finding the lack of me in these posts ver...  ENTP
# 51  Sex can be boring if it's in the same position...  ENTP
# 52               Giving new meaning to 'Game' theory.  ENTP
# 53  Hello *ENTP Grin*  That's all it takes. Than w...  ENTP
# 54  This + Lack of Balance and Hand Eye Coordination.  ENTP
#
#     sentiment_score_compound
# 0                     0.0000
# 1                     0.0000
# 2                    -0.4003
# 3                     0.0000
# 4                     0.0000
# 5                     0.0000
# 6                     0.3612
# 7                    -0.4585
# 8                     0.0000
# 9                     0.4588
# 10                    0.0000
# 11                    0.0000
# 12                    0.4019
# 13                   -0.1755
# 14                    0.8910
# 15                    0.0000
# 16                   -0.4767
# 17                    0.0000
# 18                    0.7351
# 19                    0.8023
# 20                    0.4404
# 21                   -0.2500
# 22                    0.0000
# 23                    0.0000
# 24                   -0.4588
# 25                    0.7650
# 26                    0.0000
# 27                    0.0000
# 28                    0.0000
# 29                   -0.5080
# 30                   -0.4588
# 31                    0.1501
# 32                   -0.5093
# 33                    0.0000
# 34                    0.0000
# 35                    0.5267
# 36                    0.0000
# 37                    0.0000
# 38                    0.0000
# 39                    0.0000
# 40                    0.0000
# 41                    0.3612
# 42                    0.7725
# 43                   -0.2023
# 44                    0.0000
# 45                   -0.2023
# 46                    0.0000
# 47                   -0.5719
# 48                    0.3612
# 49                    0.0000
# 50                   -0.4754
# 51                    0.0516
# 52                    0.3400
# 53                    0.7463
# 54                    0.2263

# %%
# score.to_csv('Resources/sentiment_score_raw.csv')

# %%
# types = score['type']
# score_list = score['sentiment_score_compound']
# avg = []
# count = 1
# sum = 0
# for i in range(0,len(types)-1):
#     if types[i+1] == types[i]:
#         count += 1
#         sum = sum + score_list[i+1]
#         continue
#     avgerage = sum/count
#     avg.append(avgerage)
#     sum = score_list[i+1]
#     count = 1

# %%
import numpy as np
sum = 0
average = []
a=0
for i in post_num:
    for j in range(a,a+i):
        sum += scores[j]
        avg = sum/i
    average.append(avg)
    a=a+i
len(average)
# Out:
# 8675

# %%
mbti_df['sentiment_score']=average

# %%
mbti_df=mbti_df.drop(['sentiment_score_compound'],axis=1)

# %%
mbti_df.to_csv('Resources/mbti.csv')
